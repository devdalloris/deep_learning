# %%
from tensorflow.keras.datasets  import california_housing
housing = california_housing.load_data()
(X_train, y_train), (X_test, y_test) = housing

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Normalization, InputLayer

# %%
norm_layer = Normalization(name = 'norm_layer')
model = Sequential([
    InputLayer(shape=[8], name = 'input_layer'),
    norm_layer,
    Dense(100, activation='relu', name = 'hidden1'),
    Dense(100, activation='relu', name = 'hidden2'),
    Dense(100, activation='relu', name = 'hidden3'),
    Dense(1) #output layer
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ norm_layer (Normalization)      │ (None, 8)              │            17 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden1 (Dense)                 │ (None, 100)            │           900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden2 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden3 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,218 (82.89 KB)
#  Trainable params: 21,201 (82.82 KB)
#  Non-trainable params: 17 (72.00 B)

# %%
norm_layer.adapt(X_train)

# %%
norm_layer.get_weights()
# Out:
# [array([-119.56227  ,   35.625397 ,   28.65413  , 2644.7268   ,
#          539.5743   , 1433.2728   ,  501.45834  ,    3.8701892],
#        dtype=float32),
#  array([4.0044060e+00, 4.5356297e+00, 1.5868558e+02, 4.8844355e+06,
#         1.8159067e+05, 1.3370920e+06, 1.5020797e+05, 3.6010580e+00],
#        dtype=float32),
#  np.int64(0)]

# %%
from tensorflow.keras.optimizers import Adam, SGD

# %%
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='mse', metrics=['RootMeanSquaredError'])
history = model.fit(X_train, y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - RootMeanSquaredError: 236474.4844 - loss: 55920185344.0000 - val_RootMeanSquaredError: 238059.5156 - val_loss: 56672329728.0000
# Epoch 2/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - RootMeanSquaredError: 236050.9219 - loss: 55720034304.0000 - val_RootMeanSquaredError: 237060.3281 - val_loss: 56197599232.0000
# Epoch 3/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - RootMeanSquaredError: 233920.9844 - loss: 54719029248.0000 - val_RootMeanSquaredError: 233471.5469 - val_loss: 54508961792.0000
# Epoch 4/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - RootMeanSquaredError: 228320.3594 - loss: 52130189312.0000 - val_RootMeanSquaredError: 225558.2188 - val_loss: 50876510208.0000
# Epoch 5/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - RootMeanSquaredError: 217702.1094 - loss: 47394205696.0000 - val_RootMeanSquaredError: 212042.3594 - val_loss: 44961964032.0000
# Epoch 6/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - RootMeanSquaredError: 201495.1406 - loss: 40600289280.0000 - val_RootMeanSquaredError: 193187.2031 - val_loss: 37321297920.0000
# Epoch 7/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - RootMeanSquaredError: 180834.5156 - loss: 32701120512.0000 - val_RootMeanSquaredError: 171158.2812 - val_loss: 29295159296.0000
# Epoch 8/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - RootMeanSquaredError: 158607.2188 - loss: 25156249600.0000 - val_RootMeanSquaredError: 149455.5469 - val_loss: 22336962560.0000
# Epoch 9/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - RootMeanSquaredError: 138949.3594 - loss: 19306924032.0000 - val_RootMeanSquaredError: 132270.7812 - val_loss: 17495560192.0000
# Epoch 10/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 125317.2812 - loss: 15704420352.0000 - val_RootMeanSquaredError: 121553.1797 - val_loss: 14775175168.0000
# Epoch 11/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 117497.4297 - loss: 13805645824.0000 - val_RootMeanSquaredError: 115396.0703 - val_loss: 13316252672.0000
# Epoch 12/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 112919.3203 - loss: 12750773248.0000 - val_RootMeanSquaredError: 111273.3984 - val_loss: 12381768704.0000
# Epoch 13/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 109523.4688 - loss: 11995390976.0000 - val_RootMeanSquaredError: 107861.5781 - val_loss: 11634120704.0000
# Epoch 14/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 106614.0078 - loss: 11366547456.0000 - val_RootMeanSquaredError: 104841.9609 - val_loss: 10991836160.0000
# Epoch 15/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 103995.0391 - loss: 10814967808.0000 - val_RootMeanSquaredError: 102103.9062 - val_loss: 10425207808.0000
# Epoch 16/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 101631.5859 - loss: 10328979456.0000 - val_RootMeanSquaredError: 99641.3672 - val_loss: 9928401920.0000
# Epoch 17/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 99474.2812 - loss: 9895133184.0000 - val_RootMeanSquaredError: 97382.8906 - val_loss: 9483426816.0000
# Epoch 18/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 97473.9375 - loss: 9501168640.0000 - val_RootMeanSquaredError: 95311.3672 - val_loss: 9084257280.0000
# Epoch 19/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - RootMeanSquaredError: 95639.5078 - loss: 9146915840.0000 - val_RootMeanSquaredError: 93384.6406 - val_loss: 8720691200.0000
# Epoch 20/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - RootMeanSquaredError: 93921.5391 - loss: 8821256192.0000 - val_RootMeanSquaredError: 91642.7500 - val_loss: 8398393344.0000

# %%
y_train[:5]
# Out:
# array([252300., 146900., 290900., 141300., 500001.], dtype=float32)

# %%
y_pred = model.predict(X_train)
# Out:
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
model.evaluate(X_train, y_train)
# Out:
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 92798.3984 - loss: 8611543040.0000
# [8611543040.0, 92798.3984375]

# %%
from tensorflow.keras.metrics import R2Score

# %%
score = R2Score()
score.update_state(y_train, y_pred)

# %%
score.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.3535255193710327>

# %% [markdown]
# ## Functional API

# %%
from tensorflow.keras.datasets  import california_housing
housing = california_housing.load_data()
(X_train, y_train), (X_test, y_test) = housing

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Normalization, Input, Concatenate

# %%
input_ = Input(shape=[8])
normalization_layer = Normalization()
hidden_layer1 = Dense(30, activation='relu')
hidden_layer2 = Dense(30, activation='relu')
concat_layer = Concatenate() 
output_layer = Dense(1)

normalized = normalization_layer(input_)
hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)
concatenated = concat_layer([input_, hidden2])
output = output_layer(concatenated)

model = Model(inputs = [input_], outputs = [output])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 8)         │         17 │ input_layer[0][0] │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 30)        │        270 │ normalization[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 30)        │        930 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 38)        │          0 │ input_layer[0][0… │
# │ (Concatenate)       │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         39 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,256 (4.91 KB)
#  Trainable params: 1,239 (4.84 KB)
#  Non-trainable params: 17 (72.00 B)

# %%
model.save('deep_and_wide_model.keras')

# %% [markdown]
# ## Subclass API

# %%
from tensorflow.keras.datasets  import boston_housing
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Normalization, Input, Concatenate
housing = boston_housing.load_data()
(X_train, y_train), (X_test, y_test) = housing
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 3us/step

# %%
class MyModel(Model):
    def __init__(self, units=30, activation='relu', **kwargs):
        super().__init__(**kwargs)
        self.norm_layer=Normalization()
        self.hidden1=Dense(units, activation)
        self.hidden2=Dense(units, activation)
        self.out=Dense(1)
    def call(self, X):
        X=self.norm_layer(X)
        X=self.hidden1(X)
        X=self.hidden2(X)
        X=self.out(X)
        return X
my_model = MyModel(units=50)
my_model.norm_layer.adapt(X_train)

# %%
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate = 0.001)
my_model.compile(optimizer=optimizer, loss='mse', metrics=['RootMeanSquaredError'])
history=my_model.fit(X_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - RootMeanSquaredError: 3.3486 - loss: 11.2128 - val_RootMeanSquaredError: 4.1640 - val_loss: 17.3388
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - RootMeanSquaredError: 3.2966 - loss: 10.8677 - val_RootMeanSquaredError: 4.1880 - val_loss: 17.5390
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - RootMeanSquaredError: 3.2446 - loss: 10.5275 - val_RootMeanSquaredError: 4.1695 - val_loss: 17.3845
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - RootMeanSquaredError: 3.2060 - loss: 10.2785 - val_RootMeanSquaredError: 4.1764 - val_loss: 17.4423
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - RootMeanSquaredError: 3.1879 - loss: 10.1626 - val_RootMeanSquaredError: 4.1253 - val_loss: 17.0182
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - RootMeanSquaredError: 3.1764 - loss: 10.0894 - val_RootMeanSquaredError: 4.1367 - val_loss: 17.1127
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - RootMeanSquaredError: 3.1454 - loss: 9.8936 - val_RootMeanSquaredError: 4.0506 - val_loss: 16.4072
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - RootMeanSquaredError: 3.1156 - loss: 9.7068 - val_RootMeanSquaredError: 4.1258 - val_loss: 17.0225
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - RootMeanSquaredError: 3.1118 - loss: 9.6833 - val_RootMeanSquaredError: 4.0455 - val_loss: 16.3660
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - RootMeanSquaredError: 3.0773 - loss: 9.4698 - val_RootMeanSquaredError: 4.0564 - val_loss: 16.4541

# %%
out=my_model(X_train)

# %%
out
# Out:
# <tf.Tensor: shape=(404, 1), dtype=float32, numpy=
# array([[15.180723 ],
#        [40.888878 ],
#        [37.39276  ],
#        [21.19357  ],
#        [19.653824 ],
#        [17.711615 ],
#        [13.205507 ],
#        [12.746481 ],
#        [15.443058 ],
#        [14.508023 ],
#        [14.400738 ],
#        [11.854289 ],
#        [23.106153 ],
#        [19.562618 ],
#        [17.325571 ],
#        [ 7.82253  ],
#        [51.916397 ],
#        [25.535717 ],
#        [24.414114 ],
#        [23.684076 ],
#        [12.485054 ],
#        [29.140364 ],
#        [32.18181  ],
#        [28.37289  ],
#        [19.09825  ],
#        [15.497777 ],
#        [18.32594  ],
#        [32.669292 ],
#        [14.327441 ],
#        [17.074621 ],
#        [21.837294 ],
#        [16.993465 ],
#        [13.921358 ],
#        [20.199615 ],
#        [34.52088  ],
#        [23.762325 ],
#        [13.161884 ],
#        [14.652363 ],
#        [20.89611  ],
#        [18.622124 ],
#        [20.159496 ],
#        [26.229715 ],
#        [22.38406  ],
#        [17.49505  ],
#        [16.664345 ],
#        [15.125745 ],
#        [16.457806 ],
#        [18.145763 ],
#        [32.402817 ],
#        [18.363518 ],
#        [20.993113 ],
#        [11.93083  ],
#        [33.953472 ],
#        [23.594995 ],
#        [20.123232 ],
#        [20.507437 ],
#        [14.965371 ],
#        [11.588408 ],
#        [30.830214 ],
#        [30.35299  ],
#        [21.2943   ],
#        [24.550354 ],
#        [16.081108 ],
#        [17.861824 ],
#        [14.024586 ],
#        [14.762949 ],
#        [14.40561  ],
#        [ 9.110625 ],
#        [ 9.575255 ],
#        [17.347895 ],
#        [23.35052  ],
#        [ 9.272995 ],
#        [33.954536 ],
#        [14.843385 ],
#        [12.7519245],
#        [15.483034 ],
#        [10.064558 ],
#        [16.161217 ],
#        [15.734945 ],
#        [11.672388 ],
#        [27.122757 ],
#        [41.590977 ],
#        [17.078535 ],
#        [26.411564 ],
#        [19.24174  ],
#        [21.716679 ],
#        [16.673792 ],
#        [45.723007 ],
#        [13.561961 ],
#        [12.243125 ],
#        [27.838493 ],
#        [47.98035  ],
#        [22.984045 ],
#        [39.951748 ],
#        [44.688576 ],
#        [20.399645 ],
#        [30.819176 ],
#        [23.003872 ],
#        [32.40443  ],
#        [26.595692 ],
#        [41.84034  ],
#        [45.84117  ],
#        [17.07089  ],
#        [29.005281 ],
#        [16.989931 ],
#        [23.603754 ],
#        [12.785501 ],
#        [22.821743 ],
#        [15.576249 ],
#        [22.126888 ],
#        [18.13886  ],
#        [41.46596  ],
#        [22.929502 ],
#        [15.090148 ],
#        [24.301685 ],
#        [31.857897 ],
#        [18.430523 ],
#        [15.980615 ],
#        [15.670973 ],
#        [20.914604 ],
#        [27.486397 ],
#        [17.181118 ],
#        [ 8.492388 ],
#        [39.395874 ],
#        [11.236103 ],
#        [14.41887  ],
#        [17.475285 ],
#        [29.854797 ],
#        [28.16832  ],
#        [22.70925  ],
#        [22.13661  ],
#        [17.716011 ],
#        [34.458366 ],
#        [31.006756 ],
#        [17.62948  ],
#        [20.339216 ],
#        [12.879033 ],
#        [51.01689  ],
#        [17.28097  ],
#        [ 6.9717507],
#        [19.465935 ],
#        [21.15064  ],
#        [19.521711 ],
#        [18.330332 ],
#        [28.199787 ],
#        [19.253498 ],
#        [23.103745 ],
#        [18.229584 ],
#        [13.210055 ],
#        [24.637775 ],
#        [12.362026 ],
#        [26.866606 ],
#        [24.988283 ],
#        [21.439985 ],
#        [22.15341  ],
#        [19.393421 ],
#        [ 6.209177 ],
#        [25.326605 ],
#        [24.33287  ],
#        [21.84496  ],
#        [17.096405 ],
#        [32.407383 ],
#        [17.451174 ],
#        [37.481518 ],
#        [22.54625  ],
#        [23.404188 ],
#        [22.078869 ],
#        [25.345003 ],
#        [27.070854 ],
#        [18.602419 ],
#        [25.414295 ],
#        [27.339998 ],
#        [21.619173 ],
#        [19.304882 ],
#        [18.11079  ],
#        [17.987925 ],
#        [10.587285 ],
#        [26.596281 ],
#        [13.142098 ],
#        [20.851467 ],
#        [18.67931  ],
#        [22.083782 ],
#        [32.057255 ],
#        [28.098845 ],
#        [20.76942  ],
#        [11.012584 ],
#        [19.954193 ],
#        [19.83903  ],
#        [19.787949 ],
#        [25.881563 ],
#        [12.553222 ],
#        [46.72836  ],
#        [24.836317 ],
#        [35.533222 ],
#        [18.620783 ],
#        [15.150453 ],
#        [32.119244 ],
#        [10.04163  ],
#        [22.67461  ],
#        [22.32594  ],
#        [23.948887 ],
#        [13.913794 ],
#        [24.76875  ],
#        [24.057764 ],
#        [15.985667 ],
#        [17.597382 ],
#        [15.259907 ],
#        [18.544674 ],
#        [15.760924 ],
#        [18.830317 ],
#        [24.886583 ],
#        [12.930581 ],
#        [23.404634 ],
#        [20.808826 ],
#        [13.360378 ],
#        [25.81688  ],
#        [22.375578 ],
#        [19.107723 ],
#        [24.164442 ],
#        [21.255957 ],
#        [19.005247 ],
#        [15.261281 ],
#        [22.486876 ],
#        [17.76175  ],
#        [26.334602 ],
#        [32.130222 ],
#        [31.630356 ],
#        [18.331993 ],
#        [26.644512 ],
#        [32.75071  ],
#        [31.34439  ],
#        [17.390488 ],
#        [22.181208 ],
#        [43.628178 ],
#        [21.29201  ],
#        [26.503061 ],
#        [15.652185 ],
#        [12.588186 ],
#        [20.879072 ],
#        [19.850239 ],
#        [18.125153 ],
#        [10.243818 ],
#        [20.628527 ],
#        [21.284641 ],
#        [22.244692 ],
#        [20.297932 ],
#        [33.75672  ],
#        [15.538767 ],
#        [ 5.846454 ],
#        [13.057525 ],
#        [14.542979 ],
#        [21.020185 ],
#        [11.807496 ],
#        [11.735781 ],
#        [12.73807  ],
#        [17.20984  ],
#        [18.675808 ],
#        [31.415531 ],
#        [12.944632 ],
#        [33.84854  ],
#        [44.185505 ],
#        [12.808415 ],
#        [24.034298 ],
#        [32.642784 ],
#        [27.05848  ],
#        [17.543896 ],
#        [17.76816  ],
#        [37.276775 ],
#        [21.621477 ],
#        [22.55753  ],
#        [15.169971 ],
#        [23.43079  ],
#        [29.201504 ],
#        [21.501646 ],
#        [20.621773 ],
#        [23.090202 ],
#        [32.74902  ],
#        [24.525942 ],
#        [18.865091 ],
#        [37.00344  ],
#        [14.926982 ],
#        [18.008678 ],
#        [11.771752 ],
#        [22.592632 ],
#        [ 7.768987 ],
#        [11.49803  ],
#        [ 9.309215 ],
#        [13.584028 ],
#        [13.940249 ],
#        [21.695494 ],
#        [27.875269 ],
#        [19.97923  ],
#        [19.37818  ],
#        [21.374727 ],
#        [21.56569  ],
#        [18.7237   ],
#        [34.362503 ],
#        [16.041775 ],
#        [29.644033 ],
#        [ 9.689797 ],
#        [22.857983 ],
#        [17.511366 ],
#        [16.05546  ],
#        [28.546629 ],
#        [15.413104 ],
#        [16.71046  ],
#        [39.1451   ],
#        [22.329144 ],
#        [19.852282 ],
#        [32.216724 ],
#        [23.998257 ],
#        [19.890608 ],
#        [25.987162 ],
#        [ 9.831066 ],
#        [45.264015 ],
#        [16.27072  ],
#        [16.57197  ],
#        [49.178345 ],
#        [46.161728 ],
#        [18.631817 ],
#        [20.06296  ],
#        [41.14056  ],
#        [18.515453 ],
#        [26.314335 ],
#        [18.545048 ],
#        [32.157406 ],
#        [17.691698 ],
#        [19.919924 ],
#        [17.068525 ],
#        [22.96427  ],
#        [24.778555 ],
#        [19.291996 ],
#        [30.64782  ],
#        [19.463947 ],
#        [33.715637 ],
#        [13.479627 ],
#        [33.229996 ],
#        [32.644585 ],
#        [12.705541 ],
#        [15.732443 ],
#        [15.395864 ],
#        [14.76862  ],
#        [32.690582 ],
#        [27.126701 ],
#        [45.27133  ],
#        [39.706642 ],
#        [24.251945 ],
#        [16.140064 ],
#        [43.75928  ],
#        [43.83475  ],
#        [21.25488  ],
#        [20.126097 ],
#        [26.344643 ],
#        [28.896011 ],
#        [50.067566 ],
#        [22.50812  ],
#        [25.237823 ],
#        [25.48702  ],
#        [16.36626  ],
#        [18.459332 ],
#        [18.90932  ],
#        [42.686787 ],
#        [19.953087 ],
#        [36.89173  ],
#        [17.85104  ],
#        [16.087067 ],
#        [33.318577 ],
#        [25.662975 ],
#        [18.484987 ],
#        [13.703825 ],
#        [17.635921 ],
#        [21.905024 ],
#        [30.731976 ],
#        [21.57969  ],
#        [24.15389  ],
#        [35.224125 ],
#        [26.655025 ],
#        [15.688043 ],
#        [25.967619 ],
#        [29.707798 ],
#        [24.280361 ],
#        [16.073505 ],
#        [15.390796 ],
#        [33.68535  ],
#        [20.009071 ],
#        [22.35717  ],
#        [16.429544 ],
#        [25.634264 ],
#        [32.79765  ],
#        [15.176184 ],
#        [ 8.466081 ],
#        [22.552612 ],
#        [22.446148 ],
#        [18.02419  ],
#        [30.406612 ],
#        [ 5.71751  ],
#        [ 9.403113 ],
#        [20.225792 ],
#        [11.666788 ],
#        [19.202456 ],
#        [24.94653  ],
#        [20.371664 ],
#        [15.861374 ],
#        [30.5065   ]], dtype=float32)>

# %%
my_model.predict()
